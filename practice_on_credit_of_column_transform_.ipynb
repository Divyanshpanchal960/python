# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshpanchal960/python/blob/main/practice_on_credit_of_column_transform_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
df=pd.read_csv("/content/tips - tips.csv")
df.head(4)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2

# %%
df=df.drop(columns=['total_bill','tip','size'])

# %%
df.head(4)
# Out:
#       sex smoker  day    time
# 0  Female     No  Sun  Dinner
# 1    Male     No  Sun  Dinner
# 2    Male     No  Sun  Dinner
# 3    Male     No  Sun  Dinner

# %%
df.isnull().sum()
# Out:
# sex       0
# smoker    0
# day       0
# time      0
# dtype: int64

# %%
x=df.drop(columns=['time'])
x.head(3)
y=df['time']
y.head(3)
# Out:
# 0    Dinner
# 1    Dinner
# 2    Dinner
# Name: time, dtype: object

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder(categories=[['Male','Female'],['Yes','No']])
x_train_sex_smoker=oe.fit_transform(x_train[['sex','smoker']])
x_train_sex_smoker.shape
# Out:
# (195, 2)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_day=ohe.fit_transform(x_train[['day']])
x_train_day.shape
# Out:
# (195, 3)

# %%
x_train_transformed=np.concatenate((x_train_day,x_train_sex_smoker),axis=1)

# %%
x_train_transformed.shape
# Out:
# (195, 5)

# %%
from sklearn.compose import ColumnTransformer
Transformer=ColumnTransformer(transformers=[
      #('tnf1',SimpleImputer(),['fever']),
     ('tnf2',OrdinalEncoder(categories=[['Male','Female'],['Yes','No']]),['sex','smoker']),
     ('tnf3',OneHotEncoder(sparse_output=False,drop='first'),['day'])
     ],remainder='passthrough')

# %%
Transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tnf2',
#                                  OrdinalEncoder(categories=[['Male', 'Female'],
#                                                             ['Yes', 'No']]),
#                                  ['sex', 'smoker']),
#                                 ('tnf3',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['day'])])

# %%
Transformer.fit_transform(x_train).shape
# Out:
# (195, 5)

# %%
df=pd.read_csv('/content/credit_scoring - credit_scoring.csv')
df.head(4)
# Out:
#    Age  Gender Marital Status Education Level Employment Status  \
# 0   60    Male        Married          Master          Employed
# 1   25    Male        Married     High School        Unemployed
# 2   30  Female         Single          Master          Employed
# 3   58  Female        Married             PhD        Unemployed
#
#    Credit Utilization Ratio  Payment History  Number of Credit Accounts  \
# 0                      0.22             2685                          2
# 1                      0.20             2371                          9
# 2                      0.22             2771                          6
# 3                      0.12             1371                          2
#
#    Loan Amount  Interest Rate  Loan Term   Type of Loan
# 0      4675000           2.65         48  Personal Loan
# 1      3619000           5.19         60      Auto Loan
# 2       957000           2.76         12      Auto Loan
# 3      4731000           6.57         60      Auto Loan

# %%
df=df.drop(columns=['Age','Credit Utilization Ratio','Payment History','Number of Credit Accounts','Loan Amount','Interest Rate','Loan Term'])

# %%
df.head(4)
# Out:
#    Gender Marital Status Education Level Employment Status   Type of Loan
# 0    Male        Married          Master          Employed  Personal Loan
# 1    Male        Married     High School        Unemployed      Auto Loan
# 2  Female         Single          Master          Employed      Auto Loan
# 3  Female        Married             PhD        Unemployed      Auto Loan

# %%
df.isnull().sum()
# Out:
# Gender               0
# Marital Status       0
# Education Level      0
# Employment Status    0
# Type of Loan         0
# dtype: int64

# %%
x=df.drop(columns=['Type of Loan'])
x.head(2)
y=df['Type of Loan']
y.head(2)
# Out:
# 0    Personal Loan
# 1        Auto Loan
# Name: Type of Loan, dtype: object

# %%
x_train.head(2)
# Out:
#      Gender Marital Status Education Level Employment Status
# 147  Female       Divorced     High School     Self-Employed
# 88   Female        Married     High School        Unemployed

# %%
from sklearn.model_selection import train_test_split
x_train,x_test, y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_Gen_mar=ohe.fit_transform(x_train[['Gender','Marital Status']])
x_train_Gen_mar.shape
# Out:
# (800, 3)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe=OneHotEncoder(drop='first',sparse_output=False)
x_train_edu_emp=ohe.fit_transform(x_train[['Education Level','Employment Status']])
x_train_edu_emp.shape
# Out:
# (800, 5)

# %%
x_train_transformed=np.concatenate((x_train_edu_emp,x_train_Gen_mar),axis=1)

# %%
x_train_transformed.shape
# Out:
# (800, 8)

# %%
from sklearn.compose import ColumnTransformer
Transformer=ColumnTransformer(transformers=[
    ('tnf1',OneHotEncoder(drop='first',sparse_output=False),['Gender','Marital Status']),
    ('tnf2',OneHotEncoder(drop='first',sparse_output=False),['Education Level','Employment Status'])
    ],remainder='passthrough')

# %%
Transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('tnf1',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['Gender', 'Marital Status']),
#                                 ('tnf2',
#                                  OneHotEncoder(drop='first',
#                                                sparse_output=False),
#                                  ['Education Level', 'Employment Status'])])

# %%
Transformer.fit_transform(x_train).shape
# Out:
# (800, 8)
