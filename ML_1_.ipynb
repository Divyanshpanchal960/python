# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshpanchal960/python/blob/main/ML_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#feature engineering----> Data clean and preproccessor
#Workflow of ML---->
#data ingrstion ----> data cleaning and preproccessing---- select ML Model-----Model training-----Model evalation

# %%
#Data dividation
#data=x,y
#x=x_train, x_test
#y=y_train,y_test

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/placement - placement.csv")

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
df.shape
# Out:
# (100, 3)

# %%
x=df.drop(columns=['placed'])   ###input data
x
# Out:
#     cgpa  resume_score
# 0   8.14          6.52
# 1   6.17          5.17
# 2   8.27          8.86
# 3   6.88          7.27
# 4   7.52          7.30
# ..   ...           ...
# 95  6.33          6.38
# 96  8.23          7.76
# 97  6.65          7.78
# 98  8.14          5.63
# 99  6.09          6.61
#
# [100 rows x 2 columns]

# %%
x.shape
# Out:
# (100, 2)

# %%
y=df['placed']   ##target data
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    0
# 96    1
# 97    0
# 98    1
# 99    0
# Name: placed, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train ,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# test=20%
# train=80%

# %%
#x_train
print(x_test)
x_train
# Out:
#     cgpa  resume_score
# 83  7.60          8.08
# 53  6.00          7.16
# 70  7.12          7.41
# 45  8.10          5.44
# 44  5.47          5.92
# 39  7.50          6.19
# 22  6.16          5.77
# 80  7.83          7.70
# 10  6.18          6.35
# 0   8.14          6.52
# 18  5.94          5.88
# 30  7.36          7.15
# 73  5.76          6.48
# 33  8.43          7.73
# 90  5.85          5.56
# 4   7.52          7.30
# 76  9.40          5.50
# 77  5.88          6.92
# 12  6.09          7.01
# 31  5.92          7.02
#     cgpa  resume_score
# 55  6.94          6.87
# 88  8.07          6.07
# 26  6.27          6.47
# 42  6.90          6.91
# 69  8.06          9.06
# ..   ...           ...
# 60  5.87          6.64
# 71  7.34          8.22
# 14  7.51          6.25
# 92  5.43          6.18
# 51  6.54          7.39
#
# [80 rows x 2 columns]

# %%
print("Data Shape:",df.shape)
print(".....................")
print("x data shape:",x.shape)
print("x_train data shape:",x_train.shape)
print("x_test data shape",x_test.shape)
print("............................")
print("y data shape:",y.shape)
print("y_train data shape:",y_train.shape)
print("y_test data shape:",y_test.shape)
# Out:
# Data Shape: (100, 3)
# .....................
# x data shape: (100, 2)
# x_train data shape: (60, 2)
# x_test data shape (40, 2)
# ............................
# y data shape: (100,)
# y_train data shape: (60,)
# y_test data shape: (40,)
