# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshpanchal960/python/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("/content/archive.zip")
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.head()
df.tail()
df['coffee_name'].value_counts()
#most selling drink
# Out:
# coffee_name
# Americano with Milk    809
# Latte                  757
# Americano              564
# Cappuccino             486
# Cortado                287
# Hot Chocolate          276
# Cocoa                  239
# Espresso               129
# Name: count, dtype: int64

# %%
df['coffee_name'].value_counts().plot(kind='bar')
#sns.set(style='whitegrid')
#plt.figure(figsize=(9,5))
#sns.count(data=df,x= 'coffee_name')
plt.title("top selling drink")
plt.xlabel('coffee_name')
plt.ylabel('Count')
plt.show()
#most selling drink chart
#most selling drink(coffee_name=Americano with milk )

# %%
#most selling drink percentage
df['coffee_name'].value_counts().plot(kind='pie',autopct='%.3f')
plt.title('most selling drink percantage')
plt.xlabel('coffee_name')
plt.ylabel('count')
plt.show()

# %%
print(df.groupby('hour_of_day')['money'].sum())
# print(df.groupby('hour_of_day')['money'].sum().plot(kind='bar'))
# print(df.groupby('hour_of_day')['money'].sum().plot(kind='barh'))
print(df.groupby('hour_of_day')['money'].sum().plot(kind='line'))
plt.title("peak business hour")
plt.xlabel("hour of day")
plt.ylabel("hour wise sum of money(money)")
plt.show()
#money according to hour wise -----> sabse jyda transaction 10 baje huaa hai (peak business hour=10oclock)
# Out:
# hour_of_day
# 6       149.40
# 7      2846.02
# 8      7017.88
# 9      7264.28
# 10    10198.52
# 11     8453.10
# 12     7419.62
# 13     7028.76
# 14     7173.80
# 15     7476.02
# 16     9031.84
# 17     7659.76
# 18     7162.60
# 19     7751.96
# 20     5578.92
# 21     6397.94
# 22     3635.16
# Name: money, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
df.columns
# Out:
# Index(['hour_of_day', 'cash_type', 'money', 'coffee_name', 'Time_of_Day',
#        'Weekday', 'Month_name', 'Weekdaysort', 'Monthsort', 'Date', 'Time'],
#       dtype='object')

# %%
print(df['Time_of_Day'].value_counts()) #peak purchasing time of day 'afternoon'
print(df.groupby('Time_of_Day')['money'].sum()) #peak transaction time of day is 'night'
print(df.groupby('Time_of_Day')['money'].sum().plot(kind='bar')) #peak selling by time of day
plt.title("Sales by time of day")
plt.xlabel("Time of day")
plt.ylabel("time wise sum of money")
plt.show()
# Out:
# Time_of_Day
# Afternoon    1205
# Morning      1181
# Night        1161
# Name: count, dtype: int64
# Time_of_Day
# Afternoon    38130.04
# Morning      35929.20
# Night        38186.34
# Name: money, dtype: float64
# Axes(0.125,0.11;0.775x0.77)

# %%
#df['Time_of_Day'].value_counts().plot(kind='pie',autopct='%.2f')
df.groupby('Time_of_Day')['money'].sum().plot(kind='pie',autopct='%.2f')
plt.title("percentage of sales by time of day")
plt.xlabel("time of day")
# Out:
# Text(0.5, 0, 'time of day')

# %%
df['Weekday'].value_counts()
df.groupby('Weekday')['money'].sum().plot(kind='bar')
plt.title("sales by weekday")
plt.xlabel("Weekday")
plt.ylabel("Weekday wise sum of money")
plt.show()

# %%
print(df['Month_name'].value_counts()) #values count according to month
print(df.groupby('Month_name')['money'].sum())  #total sum of money according to month(highely revenue month)
df.groupby('Month_name')['money'].sum().plot(kind='bar') #Top selling month of coffee is 'march'
plt.title("seasonal demand pattern")
plt.xlabel("sales by month")
plt.ylabel("money")
plt.show()
# Out:
# Month_name
# Mar    494
# Oct    426
# Feb    423
# Sep    344
# Aug    272
# Dec    259
# Nov    259
# May    241
# Jul    237
# Jun    223
# Jan    201
# Apr    168
# Name: count, dtype: int64
# Month_name
# Apr     5719.56
# Aug     7613.84
# Dec     8237.74
# Feb    13215.48
# Jan     6398.86
# Jul     6915.94
# Jun     7617.76
# Mar    15891.64
# May     8164.42
# Nov     8590.54
# Oct    13891.16
# Sep     9988.64
# Name: money, dtype: float64

# %%
df['cash_type'].value_counts().plot(kind='pie',autopct='%.2f')
plt.title("payment method")
# Out:
# Text(0.5, 1.0, 'payment method')

# %%
df.head(1)
df.groupby('Date')['money'].sum().plot(kind='line')
# sns.('Date')['money'].sum().plot(kind='line')
# plt.
# Out:
# <Axes: xlabel='Date'>
