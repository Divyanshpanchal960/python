# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyanshpanchal960/python/blob/main/MLday2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Machine ------> works on number
#DATA----->Normal Distribution
#normalization in feature engineering---->normalization is a feature of engineering which is used to minimum=0 and maximum=1
#Standardization--->data ke mean value ko 0 kr deta hai aur data ke central tendency or next value ke bich ke gap ko 1 kr deta hai .. standereddzation means gap of central tendency and
#next value(standered deviation)
#z scores-----> standered scaler

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/covid_toy - covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
df['city'].value_counts()
# Out:
# city
# Kolkata      32
# Bangalore    30
# Delhi        22
# Mumbai       16
# Name: count, dtype: int64

# %%
df['cough'].value_counts()
# Out:
# cough
# Mild      62
# Strong    38
# Name: count, dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Male':0,'Female':2})
df['city']=df['city'].map({'Kolkata':0,'Bangalore':1,'Delhi':2,'Mumbai':3})
df['cough']=df['cough'].map({'Mild':1,'Strong':2})
df['has_covid']=df['has_covid'].map({'Yes':0,'No':1})

# %%
df
# Out:
#     age  gender  fever  cough  city  has_covid
# 0    60       0  103.0      1     0          1
# 1    27       0  100.0      1     2          0
# 2    42       0  101.0      1     2          1
# 3    31       2   98.0      1     0          1
# 4    65       2  101.0      1     3          1
# ..  ...     ...    ...    ...   ...        ...
# 95   12       2  104.0      1     1          1
# 96   51       2  101.0      2     0          0
# 97   20       2  101.0      1     1          1
# 98    5       2   98.0      2     3          1
# 99   10       2   98.0      2     0          0
#
# [100 rows x 6 columns]

# %%
x=df.drop(columns=['has_covid'])
x
# Out:
#     age  gender  fever  cough  city
# 0    60       0  103.0      1     0
# 1    27       0  100.0      1     2
# 2    42       0  101.0      1     2
# 3    31       2   98.0      1     0
# 4    65       2  101.0      1     3
# ..  ...     ...    ...    ...   ...
# 95   12       2  104.0      1     1
# 96   51       2  101.0      2     0
# 97   20       2  101.0      1     1
# 98    5       2   98.0      2     3
# 99   10       2   98.0      2     0
#
# [100 rows x 5 columns]

# %%
y=df['has_covid']
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    0
# 97    1
# 98    1
# 99    0
# Name: has_covid, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=21)

# %%
np.round(x_test.describe())
# Out:
#        Daily Time Spent on Site     Age  Area Income  Daily Internet Usage  \
# count                    2000.0  2000.0       2000.0                2000.0
# mean                       62.0    36.0      54207.0                 177.0
# std                        16.0     9.0      13092.0                  41.0
# min                        33.0    19.0      13996.0                 105.0
# 25%                        49.0    29.0      45633.0                 140.0
# 50%                        60.0    35.0      56181.0                 179.0
# 75%                        77.0    42.0      62670.0                 212.0
# max                        91.0    60.0      79332.0                 270.0
#
#        Gender
# count  2000.0
# mean      1.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %%
#now we will apply standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)   #fit means learn the parameters and transform means apply on that data

# %%
x_train_new=pd.DataFrame(x_train_sc,columns=x.columns)

# %%
np.round(x_train_new.describe(),3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2687308692.py in <cell line: 0>()
# ----> 1 np.round(x_train_new.describe(),3)
#
# NameError: name 'np' is not defined

# %%
import numpy as np
import pandas as pd
df1=pd.read_csv("/content/click - click.csv")
df1
# Out:
#       Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                        62.26   32     69481.85                172.83
# 1                        41.73   31     61840.26                207.17
# 2                        44.40   30     57877.15                172.83
# 3                        59.88   28     56180.93                207.17
# 4                        49.21   30     54324.73                201.58
# ...                        ...  ...          ...                   ...
# 9995                     41.73   31     61840.26                207.17
# 9996                     41.73   28     51501.38                120.49
# 9997                     55.60   39     38067.08                124.44
# 9998                     46.61   50     43974.49                123.13
# 9999                     46.61   43     60575.99                198.45
#
#                                Ad Topic Line             City  Gender  \
# ...

# %%
df=df1.drop(columns=['Ad Topic Line','Timestamp'])
df2
# Out:
#       Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                        62.26   32     69481.85                172.83
# 1                        41.73   31     61840.26                207.17
# 2                        44.40   30     57877.15                172.83
# 3                        59.88   28     56180.93                207.17
# 4                        49.21   30     54324.73                201.58
# ...                        ...  ...          ...                   ...
# 9995                     41.73   31     61840.26                207.17
# 9996                     41.73   28     51501.38                120.49
# 9997                     55.60   39     38067.08                124.44
# 9998                     46.61   50     43974.49                123.13
# 9999                     46.61   43     60575.99                198.45
#
#                  City  Gender                       Country  Clicked on Ad
# ...

# %%
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     62.26   32     69481.85                172.83
# 1                     41.73   31     61840.26                207.17
# 2                     44.40   30     57877.15                172.83
# 3                     59.88   28     56180.93                207.17
# 4                     49.21   30     54324.73                201.58
#
#               City  Gender                       Country  Clicked on Ad
# 0         Lisafort    Male  Svalbard & Jan Mayen Islands              0
# 1  West Angelabury    Male                     Singapore              0
# 2        Reyesfurt  Female                    Guadeloupe              0
# 3      New Michael  Female                        Zambia              0
# 4     West Richard  Female                         Qatar              1

# %%
df.head(2)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     62.26   32     69481.85                172.83
# 1                     41.73   31     61840.26                207.17
#
#               City Gender                       Country  Clicked on Ad
# 0         Lisafort   Male  Svalbard & Jan Mayen Islands              0
# 1  West Angelabury   Male                     Singapore              0

# %%
df['Country'].value_counts()
# Out:
# Country
# Australia           388
# Czech Republic      330
# Turkey              312
# Qatar               224
# Hong Kong           221
#                    ...
# Paraguay              1
# Mozambique            1
# Saint Barthelemy      1
# Suriname              1
# Haiti                 1
# Name: count, Length: 207, dtype: int64

# %%
df.head(1)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage      City  \
# 0                     62.26   32     69481.85                172.83  Lisafort
#
#    Gender                       Country  Clicked on Ad
# 0       0  Svalbard & Jan Mayen Islands              0

# %%
df=df1.drop(columns=['City','Country'])
df.head(3)
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     62.26   32     69481.85                172.83
# 1                     41.73   31     61840.26                207.17
# 2                     44.40   30     57877.15                172.83
#
#                          Ad Topic Line  Gender            Timestamp  \
# 0      Decentralized real-time circuit    Male  2016-06-09 21:43:05
# 1       Optional full-range projection    Male  2016-01-16 17:56:05
# 2  Total 5thgeneration standardization  Female  2016-06-29 10:50:45
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0

# %%
print(df['Gender'].value_counts())
df['Gender']=df['Gender'].map({'Male':0,'Female':1})
df.head(3)
# Out:
# Gender
# Female    5376
# Male      4624
# Name: count, dtype: int64
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     62.26   32     69481.85                172.83
# 1                     41.73   31     61840.26                207.17
# 2                     44.40   30     57877.15                172.83
#
#                          Ad Topic Line  Gender            Timestamp  \
# 0      Decentralized real-time circuit       0  2016-06-09 21:43:05
# 1       Optional full-range projection       0  2016-01-16 17:56:05
# 2  Total 5thgeneration standardization       1  2016-06-29 10:50:45
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0

# %%
x=df.drop(columns=['Clicked on Ad', 'Ad Topic Line', 'Timestamp'])
x.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Gender
# 0                     62.26   32     69481.85                172.83       0
# 1                     41.73   31     61840.26                207.17       0
# 2                     44.40   30     57877.15                172.83       1
# 3                     59.88   28     56180.93                207.17       1
# 4                     49.21   30     54324.73                201.58       1

# %%
y=df['Clicked on Ad']
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    1
# Name: Clicked on Ad, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=24)

# %%
np.round(x_train.describe(),2)
# Out:
#        Daily Time Spent on Site      Age  Area Income  Daily Internet Usage  \
# count                   8000.00  8000.00      8000.00               8000.00
# mean                      61.59    35.99     53748.25                177.92
# std                       15.74     8.54     13405.14                 40.88
# min                       32.60    19.00     13996.50                105.22
# 25%                       47.74    29.00     43974.49                140.15
# 50%                       59.59    35.00     56180.93                178.92
# 75%                       76.56    42.00     61840.26                212.67
# max                       90.97    60.00     79332.33                269.96
#
#         Gender
# count  8000.00
# mean      0.54
# std       0.50
# min       0.00
# 25%       0.00
# 50%       1.00
# 75%       1.00
# max       1.00

# %%
sc=StandardScaler()

# %%
x_train_sc=sc.fit_transform(x_train)
x_train_sc
# Out:
# array([[-1.82283897,  0.11867199, -0.05142703,  1.97421453,  0.92226175],
#        [-1.56290011, -0.70137138,  0.3080276 , -0.1245575 ,  0.92226175],
#        [ 0.54012602, -0.34992422,  0.9357751 ,  0.63554096, -1.08429087],
#        ...,
#        [-1.38748905, -0.93566949,  0.60368705,  0.9650719 , -1.08429087],
#        [ 1.75147924,  0.47011915,  0.9357751 ,  1.07785124, -1.08429087],
#        [-0.38078207, -0.11562612,  0.1636628 ,  1.02721062, -1.08429087]])

# %%
x_train_sc=pd.DataFrame(x_train_sc,columns=x.columns)

# %%
np.round(x_train_sc.describe())
# Out:
#        Daily Time Spent on Site     Age  Area Income  Daily Internet Usage  \
# count                    8000.0  8000.0       8000.0                8000.0
# mean                        0.0    -0.0          0.0                   0.0
# std                         1.0     1.0          1.0                   1.0
# min                        -2.0    -2.0         -3.0                  -2.0
# 25%                        -1.0    -1.0         -1.0                  -1.0
# 50%                        -0.0    -0.0          0.0                   0.0
# 75%                         1.0     1.0          1.0                   1.0
# max                         2.0     3.0          2.0                   2.0
#
#        Gender
# count  8000.0
# mean     -0.0
# std       1.0
# min      -1.0
# 25%      -1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %%
print('DataShape',df1.shape)
print('x_train_shape',x.shape)
print('x_test_shape',x_test.shape)
print('y_train_shape',y_train.shape)
print('y_test_shape',y_test.shape)
# Out:
# DataShape (10000, 10)
# x_train_shape (10000, 5)
# x_test_shape (2000, 5)
# y_train_shape (8000,)
# y_test_shape (2000,)

# %%
# Out:
# 5821    0
# 2516    1
# 4282    0
# 4173    0
# 255     1
#        ..
# 5190    0
# 1108    0
# 6269    0
# 8709    0
# 8182    0
# Name: Clicked on Ad, Length: 2000, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df.drop(columns=['fever']).isnull().sum()
# Out:
# age          0
# gender       0
# cough        0
# city         0
# has_covid    0
# dtype: int64
